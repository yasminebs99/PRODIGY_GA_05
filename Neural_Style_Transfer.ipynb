# %%
# import numpy, tensorflow and matplotlib
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import math

# import VGG 19 model and keras Model API
from tensorflow.keras.applications.vgg19 import VGG19, preprocess_input
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.models import Model

# %%
# Image Credits: Tensorflow Doc
content_path = tf.keras.utils.get_file(
'content.jpg',
'https://upload.wikimedia.org/wikipedia/commons/thumb/3/30/Vulpes_vulpes_ssp_fulvus.jpg/1200px-Vulpes_vulpes_ssp_fulvus.jpg')
style_path = tf.keras.utils.get_file(
'nature.jpg',
'https://upload.wikimedia.org/wikipedia/commons/thumb/c/c8/Altja_j%C3%B5gi_Lahemaal.jpg/800px-Altja_j%C3%B5gi_Lahemaal.jpg')



from PIL import Image

# Open the image
image = Image.open(style_path)

# Get the dimensions of the image
width, height = image.size
print(f"Width: {width}, Height: {height}")
# Out:
# Downloading data from https://upload.wikimedia.org/wikipedia/commons/thumb/c/c8/Altja_j%C3%B5gi_Lahemaal.jpg/800px-Altja_j%C3%B5gi_Lahemaal.jpg
# 166974/166974 ━━━━━━━━━━━━━━━━━━━━ 0s 1us/step
# Width: 800, Height: 537

# %%
# code to load and process image
def load_and_process_image(image_path):
	img = load_img(image_path)
	# convert image to array
	img = img_to_array(img)
	img = preprocess_input(img)
	img = np.expand_dims(img, axis=0)
	return img

# %%
def deprocess(img):
	# perform the inverse of the pre processing step
	img[:, :, 0] += 103.939
	img[:, :, 1] += 116.779
	img[:, :, 2] += 123.68
	# convert RGB to BGR
	img = img[:, :, ::-1]

	img = np.clip(img, 0, 255).astype('uint8')
	return img


def display_image(image):
	# remove one dimension if image has 4 dimension
	if len(image.shape) == 4:
		img = np.squeeze(image, axis=0)

	img = deprocess(img)

	plt.grid(False)
	plt.xticks([])
	plt.yticks([])
	plt.imshow(img)
	return

# %%
# load content image
content_img = load_and_process_image(content_path)
display_image(content_img)



from tensorflow.image import resize

content_img = tf.image.resize(content_img, (700, 577))



# Check the shape of the content image
print(f"Original shape of content image: {content_img.shape}")
# Out:
# Original shape of content image: (1, 700, 577, 3)

# %%
# load style image
style_img = load_and_process_image(style_path)
display_image(style_img)

from tensorflow.image import resize

style_img = tf.image.resize(style_img, (1000, 657))



# Check the shape of the content image
print(f"Original shape of content image: {style_img.shape}")
# Out:
# Original shape of content image: (1, 1000, 657, 3)

# %%
# this function download the VGG model and initialise it
model = VGG19(
	include_top=False,
	weights='imagenet'
)
# set training to False
model.trainable = False
# Print details of different layers

model.summary()
# Out:
# Model: "vgg19"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)           │ (None, None, None, 3)       │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, None, None, 64)      │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, None, None, 64)      │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, None, None, 64)      │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv1 (Conv2D)                │ (None, None, None, 128)     │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv2 (Conv2D)                │ (None, None, None, 128)     │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_pool (MaxPooling2D)           │ (None, None, None, 128)     │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv1 (Conv2D)                │ (None, None, None, 256)     │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv2 (Conv2D)                │ (None, None, None, 256)     │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv3 (Conv2D)                │ (None, None, None, 256)     │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv4 (Conv2D)                │ (None, None, None, 256)     │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_pool (MaxPooling2D)           │ (None, None, None, 256)     │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv1 (Conv2D)                │ (None, None, None, 512)     │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv2 (Conv2D)                │ (None, None, None, 512)     │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv3 (Conv2D)                │ (None, None, None, 512)     │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv4 (Conv2D)                │ (None, None, None, 512)     │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_pool (MaxPooling2D)           │ (None, None, None, 512)     │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv1 (Conv2D)                │ (None, None, None, 512)     │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv2 (Conv2D)                │ (None, None, None, 512)     │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv3 (Conv2D)                │ (None, None, None, 512)     │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv4 (Conv2D)                │ (None, None, None, 512)     │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_pool (MaxPooling2D)           │ (None, None, None, 512)     │               0 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 20,024,384 (76.39 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 20,024,384 (76.39 MB)

# %%
# define content model
content_layer = 'block5_conv2'
content_model = Model(
	inputs=model.input,
	outputs=model.get_layer(content_layer).output
)
content_model.summary()
# Out:
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)           │ (None, None, None, 3)       │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, None, None, 64)      │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, None, None, 64)      │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, None, None, 64)      │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv1 (Conv2D)                │ (None, None, None, 128)     │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv2 (Conv2D)                │ (None, None, None, 128)     │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_pool (MaxPooling2D)           │ (None, None, None, 128)     │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv1 (Conv2D)                │ (None, None, None, 256)     │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv2 (Conv2D)                │ (None, None, None, 256)     │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv3 (Conv2D)                │ (None, None, None, 256)     │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv4 (Conv2D)                │ (None, None, None, 256)     │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_pool (MaxPooling2D)           │ (None, None, None, 256)     │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv1 (Conv2D)                │ (None, None, None, 512)     │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv2 (Conv2D)                │ (None, None, None, 512)     │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv3 (Conv2D)                │ (None, None, None, 512)     │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv4 (Conv2D)                │ (None, None, None, 512)     │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_pool (MaxPooling2D)           │ (None, None, None, 512)     │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv1 (Conv2D)                │ (None, None, None, 512)     │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv2 (Conv2D)                │ (None, None, None, 512)     │       2,359,808 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 15,304,768 (58.38 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 15,304,768 (58.38 MB)

# %%
# define style model
style_layers = [
	'block1_conv1',
	'block3_conv1',
	'block5_conv1'
]
style_models = [Model(inputs=model.input,
					outputs=model.get_layer(layer).output) for layer in style_layers]

# %%
# Content loss
def content_loss(content, generated):
	a_C = content_model(content)
	a_G = content_model(generated) # Add this line to compute a_G
	loss = tf.reduce_mean(tf.square(a_C - a_G))
	return loss

# %%
# gram matrix
def gram_matrix(A):
	channels = int(A.shape[-1])
	a = tf.reshape(A, [-1, channels])
	n = tf.shape(a)[0]
	gram = tf.matmul(a, a, transpose_a=True)
	return gram / tf.cast(n, tf.float32)


weight_of_layer = 1. / len(style_models)

# %%
#style loss
def style_cost(style, generated):
	J_style = 0

	for style_model in style_models:
		a_S = style_model(style)
		a_G = style_model(generated)
		GS = gram_matrix(a_S)
		GG = gram_matrix(a_G)
		content_cost = tf.reduce_mean(tf.square(GS - GG))
		J_style += content_cost * weight_of_layer

	return J_style

# %%
#content loss
def content_cost(style, generated):
	J_content = 0

	for style_model in style_models:
		a_S = style_model(style)
		a_G = style_model(generated)
		GS = gram_matrix(a_S)
		GG = gram_matrix(a_G)
		content_cost = tf.reduce_mean(tf.square(GS - GG))
		J_content += content_cost * weight_of_layer

	return J_content

# %%
import time
import tensorflow as tf
import math

# List to store generated images
generated_images = []

def training_loop(content_path, style_path, iterations=50, a=10, b=1000):
    # Load and process content and style images
    content = load_and_process_image(content_path)
    style = load_and_process_image(style_path)

    # Resize images to the same dimensions
    content = tf.image.resize(content, (256, 256))
    style = tf.image.resize(style, (256, 256))

    # Initialize the generated image
    generated = tf.Variable(content, dtype=tf.float32)

    # Optimizer
    opt = tf.keras.optimizers.Adam(learning_rate=0.7)

    # Variables to track the best image and cost
    best_cost = math.inf
    best_image = None

    for i in range(iterations):
        start_time_cpu = time.process_time()
        start_time_wall = time.time()

        with tf.GradientTape() as tape:
            # Compute content and style costs
            J_content = content_cost(style, generated)
            J_style = style_cost(style, generated)
            J_total = a * J_content + b * J_style

        # Compute gradients and apply them
        grads = tape.gradient(J_total, generated)
        opt.apply_gradients([(grads, generated)])

        # Record end times
        end_time_cpu = time.process_time()
        end_time_wall = time.time()

        # Calculate CPU and wall times
        cpu_time = end_time_cpu - start_time_cpu
        wall_time = end_time_wall - start_time_wall

        # Update best image if current cost is lower
        if J_total < best_cost:
            best_cost = J_total
            best_image = generated.numpy()

        # Print performance and loss information
        print("CPU times: user {} µs, sys: {} ns, total: {} µs".format(
            int(cpu_time * 1e6),
            int((end_time_cpu - start_time_cpu) * 1e9),
            int((end_time_cpu - start_time_cpu + 1e-6) * 1e6))
        )
        print("Wall time: {:.2f} µs".format(wall_time * 1e6))
        print("Iteration: {}".format(i))
        print("Total Loss: {:e}".format(J_total))

        # Append current generated image
        generated_images.append(generated.numpy())

    return best_image

# %%
# Train the model and get best image
final_img = training_loop(content_path, style_path)
# Out:
# CPU times: user 30896263 µs, sys: 30896263789 ns, total: 30896264 µs
# Wall time: 19692070.72 µs
# Iteration: 0
# Total Loss: 1.718031e+11
# CPU times: user 30898341 µs, sys: 30898341651 ns, total: 30898342 µs
# Wall time: 18939266.68 µs
# Iteration: 1
# Total Loss: 1.541485e+11
# CPU times: user 30748539 µs, sys: 30748539887 ns, total: 30748540 µs
# Wall time: 20561966.42 µs
# Iteration: 2
# Total Loss: 1.395938e+11
# CPU times: user 31442330 µs, sys: 31442330263 ns, total: 31442331 µs
# Wall time: 19208361.15 µs
# Iteration: 3
# Total Loss: 1.272993e+11
# CPU times: user 31014146 µs, sys: 31014146613 ns, total: 31014147 µs
# Wall time: 20623633.86 µs
# Iteration: 4
# Total Loss: 1.165912e+11
# CPU times: user 31395447 µs, sys: 31395447014 ns, total: 31395448 µs
# Wall time: 19213466.17 µs
# Iteration: 5
# Total Loss: 1.070709e+11
# CPU times: user 31333812 µs, sys: 31333812383 ns, total: 31333813 µs
# Wall time: 20632912.16 µs
# Iteration: 6
# Total Loss: 9.850004e+10
# CPU times: user 31520392 µs, sys: 31520392561 ns, total: 31520393 µs
# Wall time: 19215173.96 µs
# Iteration: 7
# Total Loss: 9.071136e+10
# CPU times: user 31145792 µs, sys: 31145792187 ns, total: 31145793 µs
# Wall time: 20080247.16 µs
# Iteration: 8
# Total Loss: 8.362222e+10
# CPU times: user 31023047 µs, sys: 31023047277 ns, total: 31023048 µs
# Wall time: 19645035.74 µs
# Iteration: 9
# Total Loss: 7.718826e+10
# CPU times: user 31298723 µs, sys: 31298723211 ns, total: 31298724 µs
# Wall time: 19108493.09 µs
# Iteration: 10
# Total Loss: 7.138777e+10
# CPU times: user 30909759 µs, sys: 30909759134 ns, total: 30909760 µs
# Wall time: 20793859.96 µs
# Iteration: 11
# Total Loss: 6.622666e+10
# CPU times: user 30965287 µs, sys: 30965287303 ns, total: 30965288 µs
# Wall time: 18993751.53 µs
# Iteration: 12
# Total Loss: 6.171055e+10
# CPU times: user 30791901 µs, sys: 30791901307 ns, total: 30791902 µs
# Wall time: 20411353.59 µs
# Iteration: 13
# Total Loss: 5.782059e+10
# CPU times: user 31070797 µs, sys: 31070797006 ns, total: 31070798 µs
# Wall time: 18898670.43 µs
# Iteration: 14
# Total Loss: 5.450923e+10
# CPU times: user 30326782 µs, sys: 30326782990 ns, total: 30326783 µs
# Wall time: 21112039.33 µs
# Iteration: 15
# Total Loss: 5.169508e+10
# CPU times: user 31115061 µs, sys: 31115061426 ns, total: 31115062 µs
# Wall time: 19690308.09 µs
# Iteration: 16
# Total Loss: 4.928669e+10
# CPU times: user 30876205 µs, sys: 30876205489 ns, total: 30876206 µs
# Wall time: 18899455.55 µs
# Iteration: 17
# Total Loss: 4.718392e+10
# CPU times: user 30782838 µs, sys: 30782838326 ns, total: 30782839 µs
# Wall time: 20619466.30 µs
# Iteration: 18
# Total Loss: 4.528842e+10
# CPU times: user 31981891 µs, sys: 31981891679 ns, total: 31981892 µs
# Wall time: 19648999.69 µs
# Iteration: 19
# Total Loss: 4.351444e+10
# CPU times: user 30873655 µs, sys: 30873655602 ns, total: 30873656 µs
# Wall time: 20486481.19 µs
# Iteration: 20
# Total Loss: 4.180425e+10
# CPU times: user 31344064 µs, sys: 31344064840 ns, total: 31344065 µs
# Wall time: 19137419.22 µs
# Iteration: 21
# Total Loss: 4.012472e+10
# CPU times: user 31460211 µs, sys: 31460211870 ns, total: 31460212 µs
# Wall time: 20779317.62 µs
# Iteration: 22
# Total Loss: 3.847804e+10
# CPU times: user 31258222 µs, sys: 31258222678 ns, total: 31258223 µs
# Wall time: 19021117.21 µs
# Iteration: 23
# Total Loss: 3.687801e+10
# CPU times: user 31408695 µs, sys: 31408695131 ns, total: 31408696 µs
# Wall time: 20120303.15 µs
# Iteration: 24
# Total Loss: 3.534816e+10
# CPU times: user 31063714 µs, sys: 31063714730 ns, total: 31063715 µs
# Wall time: 19677906.27 µs
# Iteration: 25
# Total Loss: 3.391170e+10
# CPU times: user 30791160 µs, sys: 30791160381 ns, total: 30791161 µs
# Wall time: 18882292.75 µs
# Iteration: 26
# Total Loss: 3.258861e+10
# CPU times: user 30896526 µs, sys: 30896526891 ns, total: 30896527 µs
# Wall time: 20640612.13 µs
# Iteration: 27
# Total Loss: 3.138653e+10
# CPU times: user 31548008 µs, sys: 31548008457 ns, total: 31548009 µs
# Wall time: 19351444.48 µs
# Iteration: 28
# Total Loss: 3.030621e+10
# CPU times: user 31809012 µs, sys: 31809012547 ns, total: 31809013 µs
# Wall time: 21044935.94 µs
# Iteration: 29
# Total Loss: 2.933449e+10
# CPU times: user 30929181 µs, sys: 30929181470 ns, total: 30929182 µs
# Wall time: 18827669.62 µs
# Iteration: 30
# Total Loss: 2.845124e+10
# CPU times: user 30956363 µs, sys: 30956363442 ns, total: 30956364 µs
# Wall time: 22004428.39 µs
# Iteration: 31
# Total Loss: 2.763878e+10
# CPU times: user 30908483 µs, sys: 30908483465 ns, total: 30908484 µs
# Wall time: 18790587.19 µs
# Iteration: 32
# Total Loss: 2.687968e+10
# CPU times: user 31446910 µs, sys: 31446910457 ns, total: 31446911 µs
# Wall time: 20497470.62 µs
# Iteration: 33
# Total Loss: 2.615764e+10
# CPU times: user 31363658 µs, sys: 31363658151 ns, total: 31363659 µs
# Wall time: 18972780.70 µs
# Iteration: 34
# Total Loss: 2.546575e+10
# CPU times: user 30109833 µs, sys: 30109833177 ns, total: 30109834 µs
# Wall time: 18626739.03 µs
# Iteration: 35
# Total Loss: 2.479827e+10
# CPU times: user 31205479 µs, sys: 31205479205 ns, total: 31205480 µs
# Wall time: 20714831.83 µs
# Iteration: 36
# Total Loss: 2.415541e+10
# CPU times: user 30966528 µs, sys: 30966528058 ns, total: 30966529 µs
# Wall time: 19098620.89 µs
# Iteration: 37
# Total Loss: 2.354074e+10
# CPU times: user 30197967 µs, sys: 30197967856 ns, total: 30197968 µs
# Wall time: 20045699.36 µs
# Iteration: 38
# Total Loss: 2.295893e+10
# CPU times: user 30747567 µs, sys: 30747567688 ns, total: 30747568 µs
# Wall time: 18678471.33 µs
# Iteration: 39
# Total Loss: 2.241221e+10
# CPU times: user 30467150 µs, sys: 30467150521 ns, total: 30467151 µs
# Wall time: 19557160.62 µs
# Iteration: 40
# Total Loss: 2.190048e+10
# CPU times: user 30965004 µs, sys: 30965004739 ns, total: 30965005 µs
# Wall time: 19664713.62 µs
# Iteration: 41
# Total Loss: 2.142236e+10
# CPU times: user 30760623 µs, sys: 30760623981 ns, total: 30760624 µs
# Wall time: 18740771.06 µs
# Iteration: 42
# Total Loss: 2.097315e+10
# CPU times: user 30726568 µs, sys: 30726568149 ns, total: 30726569 µs
# Wall time: 20575198.65 µs
# Iteration: 43
# Total Loss: 2.054747e+10
# CPU times: user 31063395 µs, sys: 31063395312 ns, total: 31063396 µs
# Wall time: 19059745.55 µs
# Iteration: 44
# Total Loss: 2.014119e+10
# CPU times: user 30660327 µs, sys: 30660327590 ns, total: 30660328 µs
# Wall time: 20183554.65 µs
# Iteration: 45
# Total Loss: 1.974848e+10
# CPU times: user 30740481 µs, sys: 30740481238 ns, total: 30740482 µs
# Wall time: 18673778.06 µs
# Iteration: 46
# Total Loss: 1.936651e+10
# CPU times: user 31740406 µs, sys: 31740406261 ns, total: 31740407 µs
# Wall time: 20178017.14 µs
# Iteration: 47
# Total Loss: 1.899415e+10
# CPU times: user 31193080 µs, sys: 31193080091 ns, total: 31193081 µs
# Wall time: 21405692.34 µs
# Iteration: 48
# Total Loss: 1.863192e+10
# CPU times: user 30556261 µs, sys: 30556261350 ns, total: 30556262 µs
# Wall time: 19464071.04 µs
# Iteration: 49
# Total Loss: 1.828252e+10

# %%
# display best generated image
plt.figure(figsize=(12, 12))
# plot best result
display_image(final_img)
